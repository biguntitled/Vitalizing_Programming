# %% [markdown]
# # Dynamic Programming Project

# %%
import numpy as np
from scipy.stats import skewnorm
import matplotlib.pyplot as plt
import ex_post_functions as ex #Copied all the ex post functions into a single file

# %% [markdown]
# ## Creating a skewed distribution

# %%
a = 10 #level of skewedness

mean, var, skew, kurt = skewnorm.stats(a, moments='mvsk') #

# %%
x = np.linspace(skewnorm.ppf(0.01, a), skewnorm.ppf(0.99, a), 100)

# %%
rv = skewnorm(a)

plt.plot(x, rv.pdf(x), 'k-', lw=2, label='frozen pdf')

# %%
vals = skewnorm.ppf([0.001, 0.5, 0.999], a)

np.allclose([0.001, 0.5, 0.999], skewnorm.cdf(vals, a))
# Out:
# True

# %%
r = skewnorm.rvs(a, size=1000)

# %%
plt.hist(r, density=True, bins='auto', histtype='stepfilled', alpha=0.2)
plt.plot(x, rv.pdf(x), 'k-', lw=2, label='frozen pdf')
plt.show()

# %%
par = ex.setup()
